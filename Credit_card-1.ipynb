# %%
import pandas as pd

Credit_data=pd.read_excel("")

Credit_data.head()
# Out:
#    Recnum     Cardnum       Date       Merchnum        Merch description  \
# 0       1  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
# 1       2  5142183973 2010-01-01    61003026333  SERVICE MERCHANDISE #81
# 2       3  5142131721 2010-01-01  4503082993600        OFFICE DEPOT #191
# 3       4  5142148452 2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#
# 4       5  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
#
#   Merch state  Merch zip Transtype  Amount  Fraud  Unnamed: 10  Unnamed: 11  \
# 0          TN    38118.0         P    3.62      0          NaN          NaN
# 1          MA     1803.0         P   31.42      0          NaN          NaN
# 2          MD    20706.0         P  178.49      0          NaN          NaN
# 3          TN    38118.0         P    3.62      0          NaN          NaN
# 4          TN    38118.0         P    3.62      0          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# ...

# %% [markdown]
# DATA CLEANSING

# %%
Credit_data.drop(["Unnamed: 10","Unnamed: 11","Unnamed: 12","Unnamed: 13","Unnamed: 14","Unnamed: 15","Unnamed: 16","Unnamed: 17"],axis=1, inplace=True) 
Credit_data.head()
# Out:
#    Recnum     Cardnum       Date       Merchnum        Merch description  \
# 0       1  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
# 1       2  5142183973 2010-01-01    61003026333  SERVICE MERCHANDISE #81
# 2       3  5142131721 2010-01-01  4503082993600        OFFICE DEPOT #191
# 3       4  5142148452 2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#
# 4       5  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
#
#   Merch state  Merch zip Transtype  Amount  Fraud
# 0          TN    38118.0         P    3.62      0
# 1          MA     1803.0         P   31.42      0
# 2          MD    20706.0         P  178.49      0
# 3          TN    38118.0         P    3.62      0
# 4          TN    38118.0         P    3.62      0

# %%
Credit_data.set_index("Recnum",inplace=True)
Credit_data.head()
# Out:
#            Cardnum       Date       Merchnum        Merch description  \
# Recnum
# 1       5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
# 2       5142183973 2010-01-01    61003026333  SERVICE MERCHANDISE #81
# 3       5142131721 2010-01-01  4503082993600        OFFICE DEPOT #191
# 4       5142148452 2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#
# 5       5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
#
#        Merch state  Merch zip Transtype  Amount  Fraud
# Recnum
# 1               TN    38118.0         P    3.62      0
# 2               MA     1803.0         P   31.42      0
# 3               MD    20706.0         P  178.49      0
# 4               TN    38118.0         P    3.62      0
# 5               TN    38118.0         P    3.62      0

# %%
Credit_data.dtypes
# Out:
# Cardnum                       int64
# Date                 datetime64[ns]
# Merchnum                     object
# Merch description            object
# Merch state                  object
# Merch zip                   float64
# Transtype                    object
# Amount                      float64
# Fraud                         int64
# dtype: object

# %%
Credit_data['year']= Credit_data['Date'].dt.year
Credit_data['month']= Credit_data['Date'].dt.month
Credit_data['day']= Credit_data['Date'].dt.day
Credit_data.head()
# Out:
#            Cardnum       Date       Merchnum        Merch description  \
# Recnum
# 1       5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
# 2       5142183973 2010-01-01    61003026333  SERVICE MERCHANDISE #81
# 3       5142131721 2010-01-01  4503082993600        OFFICE DEPOT #191
# 4       5142148452 2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#
# 5       5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
#
#        Merch state  Merch zip Transtype  Amount  Fraud  year  month  day
# Recnum
# 1               TN    38118.0         P    3.62      0  2010      1    1
# 2               MA     1803.0         P   31.42      0  2010      1    1
# 3               MD    20706.0         P  178.49      0  2010      1    1
# 4               TN    38118.0         P    3.62      0  2010      1    1
# 5               TN    38118.0         P    3.62      0  2010      1    1

# %%
Credit_data.nunique()
# Out:
# Cardnum               1645
# Date                   365
# Merchnum             13091
# Merch description    13126
# Merch state            227
# Merch zip             4567
# Transtype                4
# Amount               34909
# Fraud                    2
# year                     1
# month                   12
# day                     31
# dtype: int64

# %%
Credit_data.drop(["year","Date"],axis=1, inplace=True) 
Credit_data.head()
# Out:
#            Cardnum       Merchnum        Merch description Merch state  \
# Recnum
# 1       5142190439  5509006296254   FEDEX SHP 12/23/09 AB#          TN
# 2       5142183973    61003026333  SERVICE MERCHANDISE #81          MA
# 3       5142131721  4503082993600        OFFICE DEPOT #191          MD
# 4       5142148452  5509006296254   FEDEX SHP 12/28/09 AB#          TN
# 5       5142190439  5509006296254   FEDEX SHP 12/23/09 AB#          TN
#
#         Merch zip Transtype  Amount  Fraud  month  day
# Recnum
# 1         38118.0         P    3.62      0      1    1
# 2          1803.0         P   31.42      0      1    1
# 3         20706.0         P  178.49      0      1    1
# 4         38118.0         P    3.62      0      1    1
# 5         38118.0         P    3.62      0      1    1

# %%
Credit_data=Credit_data[["day","month","Cardnum","Merchnum","Merch description","Merch state","Merch zip","Transtype","Amount","Fraud"]]
Credit_data.head()
# Out:
#         day  month     Cardnum       Merchnum        Merch description  \
# Recnum
# 1         1      1  5142190439  5509006296254   FEDEX SHP 12/23/09 AB#
# 2         1      1  5142183973    61003026333  SERVICE MERCHANDISE #81
# 3         1      1  5142131721  4503082993600        OFFICE DEPOT #191
# 4         1      1  5142148452  5509006296254   FEDEX SHP 12/28/09 AB#
# 5         1      1  5142190439  5509006296254   FEDEX SHP 12/23/09 AB#
#
#        Merch state  Merch zip Transtype  Amount  Fraud
# Recnum
# 1               TN    38118.0         P    3.62      0
# 2               MA     1803.0         P   31.42      0
# 3               MD    20706.0         P  178.49      0
# 4               TN    38118.0         P    3.62      0
# 5               TN    38118.0         P    3.62      0

# %%
Credit_data.isnull().sum()
# Out:
# day                     0
# month                   0
# Cardnum                 0
# Merchnum             3375
# Merch description       0
# Merch state          1195
# Merch zip            4656
# Transtype               0
# Amount                  0
# Fraud                   0
# dtype: int64

# %%
Credit_data.dropna(axis=0,inplace=True)
Credit_data.isnull().sum()
# Out:
# day                  0
# month                0
# Cardnum              0
# Merchnum             0
# Merch description    0
# Merch state          0
# Merch zip            0
# Transtype            0
# Amount               0
# Fraud                0
# dtype: int64

# %%
Credit_data.shape
# Out:
# (90198, 10)

# %%
Credit_data.duplicated().sum()
# Out:
# 6003

# %%
Credit_data.drop_duplicates()
# Out:
#         day  month     Cardnum       Merchnum        Merch description  \
# Recnum
# 1         1      1  5142190439  5509006296254   FEDEX SHP 12/23/09 AB#
# 2         1      1  5142183973    61003026333  SERVICE MERCHANDISE #81
# 3         1      1  5142131721  4503082993600        OFFICE DEPOT #191
# 4         1      1  5142148452  5509006296254   FEDEX SHP 12/28/09 AB#
# 6         1      1  5142149874  5509006296254   FEDEX SHP 12/22/09 AB#
# ...     ...    ...         ...            ...                      ...
# 96749    31     12  5142276053  3500000006160   BEST BUY      00001610
# 96750    31     12  5142225701  8090710030950   MARKUS OFFICE SUPPLIES
# 96751    31     12  5142226486  4503057341100            TECH PAC, INC
# 96752    31     12  5142244619  8834000695412                  BUY.COM
# 96753    31     12  5142243247  9108347680006    STAPLES NATIONAL #471
#
#        Merch state  Merch zip Transtype   Amount  Fraud
# Recnum
# ...

# %%
Credit_data.nunique()
# Out:
# day                     31
# month                   12
# Cardnum               1622
# Merchnum             12807
# Merch description    12184
# Merch state             51
# Merch zip             4452
# Transtype                1
# Amount               33878
# Fraud                    2
# dtype: int64

# %%
Credit_data.drop(["Transtype"],axis=1, inplace=True) 
Credit_data.head()
# Out:
#         day  month     Cardnum       Merchnum        Merch description  \
# Recnum
# 1         1      1  5142190439  5509006296254   FEDEX SHP 12/23/09 AB#
# 2         1      1  5142183973    61003026333  SERVICE MERCHANDISE #81
# 3         1      1  5142131721  4503082993600        OFFICE DEPOT #191
# 4         1      1  5142148452  5509006296254   FEDEX SHP 12/28/09 AB#
# 5         1      1  5142190439  5509006296254   FEDEX SHP 12/23/09 AB#
#
#        Merch state  Merch zip  Amount  Fraud
# Recnum
# 1               TN    38118.0    3.62      0
# 2               MA     1803.0   31.42      0
# 3               MD    20706.0  178.49      0
# 4               TN    38118.0    3.62      0
# 5               TN    38118.0    3.62      0

# %%
Credit_data[Credit_data.columns[1:]].corr()['Fraud'][:]
# Out:
# month        0.037741
# Cardnum      0.042390
# Merch zip    0.032984
# Amount       0.217197
# Fraud        1.000000
# Name: Fraud, dtype: float64

# %%
Credit_data.drop(["day","Merchnum","Merch description","Merch state"],axis=1, inplace=True) 
Credit_data.head()
# Out:
#         month     Cardnum  Merch zip  Amount  Fraud
# Recnum
# 1           1  5142190439    38118.0    3.62      0
# 2           1  5142183973     1803.0   31.42      0
# 3           1  5142131721    20706.0  178.49      0
# 4           1  5142148452    38118.0    3.62      0
# 5           1  5142190439    38118.0    3.62      0

# %% [markdown]
# DATA ANALYSIS

# %%
import seaborn as sns
import matplotlib.pyplot as plt

colors = sns.color_palette('bright')[0:5]
sns.set(style="darkgrid")
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
Credit_data['Fraud'].value_counts().plot(kind = 'pie', autopct = '%.2f%%',colors = colors)
plt.subplot(1,2,2)
sns.countplot(x = 'Fraud', data = Credit_data,palette='bright')
plt.show()
Credit_data["Fraud"].value_counts()
# Out:
# 0    89176
# 1     1022
# Name: Fraud, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,7))
plt.title('MONTH')
sns.countplot(data=Credit_data,x=Credit_data['month'])
plt.show()

# %%
plt.figure(figsize=(20,10))
ax=sns.countplot(x='month', hue="Fraud", data=Credit_data,palette='crest')
plt.xticks(size=12)
plt.xlabel('month',size=12)
plt.yticks(size=12)
plt.ylabel('count',size=12)
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize = (10,5))
sns.boxplot(x="Fraud",y="month",data=Credit_data,palette='bright')
# Out:
# <AxesSubplot:xlabel='Fraud', ylabel='month'>

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax=sns.histplot(x='Amount',data=Credit_data[Credit_data.Amount<=1000],stat='density',
                multiple='dodge',common_norm=False,bins=25,palette='bright')

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax=sns.histplot(x='Amount',data=Credit_data[Credit_data.Amount<=1000],hue='Fraud',stat='density',
                multiple='dodge',common_norm=False,bins=25,palette='bright')
ax.set_ylabel('Percentage in Each Type')
ax.set_xlabel('Transaction Amount')
plt.legend(title='Type', labels=['Fraud', 'Not Fraud'])

# %%
sns.pairplot(Credit_data)

# %%
plt.figure(figsize=[10,8])
sns.heatmap(Credit_data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import numpy as np

# %%
X=Credit_data.drop(["Fraud"],axis=1)
y=Credit_data["Fraud"]

train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

#print(X_train)

standard_deviation_trained= np.std(X_train)
print("standard deviation of train data",standard_deviation_trained)

mean_trained=X_train.mean()
print("mean of train data",mean_trained)
# Out:
# standard deviation of train data month            3.212289
# Cardnum      56036.848940
# Merch zip    28254.674123
# Amount         815.324123
# dtype: float64
# mean of train data month        6.333865e+00
# Cardnum      5.142201e+09
# Merch zip    4.457746e+04
# Amount       3.968661e+02
# dtype: float64

# %%
#print(X_test)

standard_deviation_test= np.std(X_test)
print("standard deviation of test data",standard_deviation_test)

mean_test=X_test.mean()
print("mean of test data",mean_test)
# Out:
# standard deviation of test data month            3.205079
# Cardnum      55337.016463
# Merch zip    28329.450844
# Amount         820.100328
# dtype: float64
# mean of test data month        6.264856e+00
# Cardnum      5.142202e+09
# Merch zip    4.459935e+04
# Amount       3.988697e+02
# dtype: float64

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import keras
from keras import layers
from keras.datasets import mnist, fashion_mnist
import numpy as np
from ipywidgets import interact
from keras import backend as K
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler().fit(X_train)
scaler.transform(X_train)
X_train_scaled=scaler.transform(X_train)


scaler=StandardScaler().fit(X_test)
scaler.transform(X_test)
X_test_scaled=scaler.transform(X_test)

# %%
#print(X_train_scaled)

standard_deviation_trained= np.std(X_train_scaled)
print("standard deviation of scaled train data",standard_deviation_trained)

mean_trained=X_train_scaled.mean()
print("mean of scaled train data",mean_trained)
# Out:
# standard deviation of scaled train data 0.9999999999999999
# mean of scaled train data -1.339756796069248e-13

# %%
#print(X_test_scaled)

standard_deviation_test= np.std(X_test_scaled)
print("standard deviation of scaled test data",standard_deviation_test)

mean_test=X_test_scaled.mean()
print("mean of scaled test data",mean_test)
# Out:
# standard deviation of scaled test data 1.0
# mean of scaled test data -2.8275425853873354e-13

# %%
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()
logmodel.fit(X_train_scaled,y_train)
predictions=logmodel.predict(X_test_scaled)

from sklearn.metrics import classification_report
classification_report(y_test,predictions)

acc_logmodel = round(logmodel.score(X_train_scaled, y_train) * 100, 2)
print(round(acc_logmodel ,2,), "%")
# Out:
# 98.82 %

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=3)
random_forest.fit(X_train_scaled, y_train)

y_prediction = random_forest.predict(X_test_scaled)

random_forest.score(X_train_scaled, y_train)
acc_random_forest = round(random_forest.score(X_train_scaled, y_train) * 100, 2)
print(round(acc_random_forest,2,), "%")
# Out:
# 99.95 %
